# %%
# !pip install roboflow ultralytics tensorflowjs -q

import os
from google.colab import userdata
from roboflow import Roboflow
from torch.utils.data import DataLoader
from ultralytics import YOLO
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.3/41.3 kB 1.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 250.0/250.0 kB 9.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.8/66.8 kB 4.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.9/49.9 MB 20.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 23.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 89.1/89.1 kB 4.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.2/53.2 kB 1.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.0/53.0 kB 2.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 21.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.5/5.5 MB 56.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.1/16.1 MB 24.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 645.0/645.0 MB 2.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 62.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.5/5.5 MB 108.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 72.5/72.5 kB 3.9 MB/s eta 0:00:00
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# tensorflow-text 2.20.1 requires tensorflow<2.21,>=2.20.0, but you have tensorflow 2.19.0 which is incompatible.
# ydf-tf 2.20.0 requires tensorflow==2.20.0, but you have tensorflow 2.19.0 which is incompatible.
# google-cloud-bigquery 3.41.0 requires packaging>=24.2.0, but you have packaging 23.2 which is incompatible.
# xarray 2025.12.0 requires packaging>=24.1, but you have packaging 23.2 which is incompatible.
# bigquery-magics 0.14.0 requires packaging>=24.2.0, but you have packaging 23.2 which is incompatible.
# db-dtypes 1.7.0 requires packaging>=24.2.0, but you have packaging 23.2 which is incompatible.
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.

# %%
rf = Roboflow(api_key=userdata.get('RoboflowAPIKey'))
project = rf.workspace("duc-nguyen-asf36").project("school-supplies-gz456")
version = project.version(1)
dataset = version.download("yolov8")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# Downloading Dataset Version Zip in school-supplies-1 to yolov8:: 100%|██████████| 289393/289393 [00:13<00:00, 22244.87it/s]
# Extracting Dataset Version Zip to school-supplies-1 in yolov8:: 100%|██████████| 15915/15915 [00:03<00:00, 4007.88it/s]

# %%
import os
model = YOLO('yolo26n.pt')
data_yaml_path = os.path.join('/content', project.name.replace(' ', '-') + '-' + str(version.version), 'data.yaml')
results = model.train(data=data_yaml_path, epochs=1, imgsz=640, batch=-1, device=0)
# Out:
# Downloading https://github.com/ultralytics/assets/releases/download/v8.4.0/yolo26n.pt to 'yolo26n.pt': 100% ━━━━━━━━━━━━ 5.3MB 105.8MB/s 0.0s
# Ultralytics 8.4.75 🚀 Python-3.12.13 torch-2.11.0+cpu
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_2007/805633244.py in <cell line: 0>()
#       2 model = YOLO('yolo26n.pt')
#       3 data_yaml_path = os.path.join('/content', project.name.replace(' ', '-') + '-' + str(version.version), 'data.yaml')
# ----> 4 results = model.train(data=data_yaml_path, epochs=1, imgsz=640, batch=-1, device=0)
#
# /usr/local/lib/python3.12/dist-packages/ultralytics/engine/model.py in train(self, trainer, **kwargs)
#     781                     args["resume"] = False
#     782
# --> 783         self.trainer = (trainer or self._smart_load("trainer"))(overrides=args, _callbacks=self.callbacks)
#     784         if not args.get("resume") and self.ckpt:
#     785             # Reuse the already-loaded checkpoint model to avoid re-resolving remote weight sources during trainer setup.
#
# /usr/local/lib/python3.12/dist-packages/ultralytics/models/yolo/detect/train.py in __init__(self, cfg, overrides, _callbacks)
#      61             _callbacks (dict, optional): Dictionary of callback functions to be executed during training.
#      62         """
# ---> 63         super().__init__(cfg, overrides, _callbacks)
#      64
#      65     def build_dataset(self, img_path: str, mode: str = "train", batch: int | None = None):
#
# /usr/local/lib/python3.12/dist-packages/ultralytics/engine/trainer.py in __init__(self, cfg, overrides, _callbacks)
#     126         self.args = get_cfg(cfg, overrides)
#     127         self.check_resume(overrides)
# --> 128         self.device = select_device(self.args.device)
#     129         # Update "-1" devices so post-training val does not repeat search
#     130         self.args.device = os.getenv("CUDA_VISIBLE_DEVICES") if "cuda" in str(self.device) else str(self.device)
#
# /usr/local/lib/python3.12/dist-packages/ultralytics/utils/torch_utils.py in select_device(device, newline, verbose)
#     229                 else ""
#     230             )
# --> 231             raise ValueError(
#     232                 f"Invalid CUDA 'device={device}' requested."
#     233                 f" Use 'device=cpu' or pass valid CUDA device(s) if available,"
#
# ValueError: Invalid CUDA 'device=0' requested. Use 'device=cpu' or pass valid CUDA device(s) if available, i.e. 'device=0' or 'device=0,1,2,3' for Multi-GPU.
#
# torch.cuda.is_available(): False
# torch.cuda.device_count(): 0
# os.environ['CUDA_VISIBLE_DEVICES']: None
# See https://pytorch.org/get-started/locally/ for up-to-date torch install instructions if no CUDA devices are seen by torch.

# %%
model.export(format="tfjs", imgsz=640)
# Out:
# Ultralytics 8.4.75 🚀 Python-3.12.13 torch-2.11.0+cpu CPU (Intel Xeon CPU @ 2.20GHz)
# 💡 ProTip: Export to OpenVINO format for best performance on Intel hardware. Learn more at https://docs.ultralytics.com/integrations/openvino/
# YOLO26n summary (fused): 122 layers, 2,408,932 parameters, 0 gradients, 5.4 GFLOPs
#
# PyTorch: starting from 'yolo26b.pt' with input shape (1, 3, 640, 640) BCHW and output shape(s) (1, 300, 6) (5.3 MB)
# requirements: Ultralytics requirements ['onnx>=1.12.0,<2.0.0', 'onnxruntime', 'onnxslim>=0.1.82'] not found, attempting AutoUpdate...
# Using Python 3.12.13 environment at: /usr
# Resolved 12 packages in 407ms
# Prepared 4 packages in 3.12s
# Installed 4 packages in 453ms
#  + colorama==0.4.6
#  + onnx==1.22.0
#  + onnxruntime==1.27.0
#  + onnxslim==0.1.94
#
# requirements: AutoUpdate success ✅ 4.8s
# WARNING ⚠️ requirements: Restart runtime or rerun command for updates to take effect
#
#
# ONNX: starting export with onnx 1.22.0 opset 20...
# Exporting aten::index operator of advanced indexing in opset 20 is achieved by combination of multiple ONNX operators, including Reshape, Transpose, Concat, and Gather. If indices include negative values, the exported graph will produce incorrect results.
# ONNX: slimming with onnxslim 0.1.94...
# ONNX: export success ✅ 7.7s, saved as 'yolo26b.onnx' (9.5 MB)
# requirements: Ultralytics requirement ['onnx2tf>=1.26.3,<1.29.0'] not found, attempting AutoUpdate...
# Using Python 3.12.13 environment at: /usr
# Resolved 1 package in 132ms
# Prepared 1 package in 83ms
# Installed 1 package in 6ms
#  + onnx2tf==1.28.8
#
# requirements: AutoUpdate success ✅ 0.3s
# WARNING ⚠️ requirements: Restart runtime or rerun command for updates to take effect
#
# requirements: Ultralytics requirements ['sng4onnx>=1.0.1', 'onnx_graphsurgeon>=0.3.26', 'ai-edge-litert>=1.2.0'] not found, attempting AutoUpdate...
# Using Python 3.12.13 environment at: /usr
# Resolved 11 packages in 2.05s
# Prepared 4 packages in 412ms
# Installed 4 packages in 8ms
#  + ai-edge-litert==2.1.5
#  + backports-strenum==1.3.1
#  + onnx-graphsurgeon==0.6.1
#  + sng4onnx==2.0.1
#
# requirements: AutoUpdate success ✅ 2.6s
# WARNING ⚠️ requirements: Restart runtime or rerun command for updates to take effect
#
#
# TensorFlow SavedModel: starting export with tensorflow 2.19.0...
# Downloading https://github.com/ultralytics/assets/releases/download/v8.4.0/calibration_image_sample_data_20x128x128x3_float32.npy.zip to 'calibration_image_sample_data_20x128x128x3_float32.npy.zip': 100% ━━━━━━━━━━━━ 1.1MB 35.4MB/s 0.0s
# Unzipping calibration_image_sample_data_20x128x128x3_float32.npy.zip to /content/calibration_image_sample_data_20x128x128x3_float32.npy...: 100% ━━━━━━━━━━━━ 1/1 38.7files/s 0.0s
# TensorFlow SavedModel: starting TFLite export with onnx2tf 1.28.8...
# Saved artifact at 'yolo26b_saved_model'. The following endpoints are available:
#
# * Endpoint 'serving_default'
#   inputs_0 (POSITIONAL_ONLY): TensorSpec(shape=(1, 640, 640, 3), dtype=tf.float32, name='images')
# Output Type:
#   TensorSpec(shape=(1, 300, 6), dtype=tf.float32, name=None)
# Captures:
#   139660846772688: TensorSpec(shape=(4, 2), dtype=tf.int32, name=None)
#   139660846771920: TensorSpec(shape=(3, 3, 3, 16), dtype=tf.float32, name=None)
#   139660846771728: TensorSpec(shape=(16,), dtype=tf.float32, name=None)
#   139660813288464: TensorSpec(shape=(4, 2), dtype=tf.int32, name=None)
#   139660846770384: TensorSpec(shape=(3, 3, 16, 32), dtype=tf.float32, name=None)
#   139660813287504: TensorSpec(shape=(32,), dtype=tf.float32, name=None)
#   139660846772880: TensorSpec(shape=(1, 1, 32, 32), dtype=tf.float32, name=None)
#   139660813288848: TensorSpec(shape=(32,), dtype=tf.float32, name=None)
#   139660813289616: TensorSpec(shape=(4,), dtype=tf.int64, name=None)
#   139660813289232: TensorSpec(shape=(4,), dtype=tf.int64, name=None)
#   139660846767120: TensorSpec(shape=(3, 3, 16, 8), dtype=tf.float32, name=None)
#   139660846764240: TensorSpec(shape=(8,), dtype=tf.float32, name=None)
#   139660813291152: TensorSpec(shape=(3, 3, 8, 16), dtype=tf.float32, name=None)
#   139660813290384: TensorSpec(shape=(16,), dtype=tf.float32, name=None)
#   139660813289040: TensorSpec(shape=(4,), dtype=tf.int64, name=None)
#   139660813290192: TensorSpec(shape=(4,), dtype=tf.int64, name=None)
#   139660813292880: TensorSpec(shape=(1, 1, 48, 64), dtype=tf.float32, name=None)
#   139660813291920: TensorSpec(shape=(64,), dtype=tf.float32, name=None)
#   139660813288656: TensorSpec(shape=(4, 2), dtype=tf.int32, name=None)
#   139660813292304: TensorSpec(shape=(3, 3, 64, 64), dtype=tf.float32, name=None)
#   139660813290960: TensorSpec(shape=(64,), dtype=tf.float32, name=None)
#   139660813293264: TensorSpec(shape=(1, 1, 64, 64), dtype=tf.float32, name=None)
#   139660813292496: TensorSpec(shape=(64,), dtype=tf.float32, name=None)
#   139660813294032: TensorSpec(shape=(4,), dtype=tf.int64, name=None)
#   139660813292688: TensorSpec(shape=(4,), dtype=tf.int64, name=None)
#   139660813294416: TensorSpec(shape=(3, 3, 32, 16), dtype=tf.float32, name=None)
#   139660813295376: TensorSpec(shape=(16,), dtype=tf.float32, name=None)
#   139660813293456: TensorSpec(shape=(3, 3, 16, 32), dtype=tf.float32, name=None)
#   139660813292112: TensorSpec(shape=(32,), dtype=tf.float32, name=None)
#   139660813293648: TensorSpec(shape=(4,), dtype=tf.int64, name=None)
#   139660813293840: TensorSpec(shape=(4,), dtype=tf.int64, name=None)
#   139660813295568: TensorSpec(shape=(1, 1, 96, 128), dtype=tf.float32, name=None)
#   139660813293072: TensorSpec(shape=(128,), dtype=tf.float32, name=None)
#   139660813295952: TensorSpec(shape=(4, 2), dtype=tf.int32, name=None)
#   139660813294608: TensorSpec(shape=(3, 3, 128, 128), dtype=tf.float32, name=None)
#   139660813295760: TensorSpec(shape=(128,), dtype=tf.float32, name=None)
#   139660813296144: TensorSpec(shape=(1, 1, 128, 128), dtype=tf.float32, name=None)
#   139660813296336: TensorSpec(shape=(128,), dtype=tf.float32, name=None)
#   139660813296912: TensorSpec(shape=(4,), dtype=tf.int64, name=None)
#   139660813296720: TensorSpec(shape=(4,), dtype=tf.int64, name=None)
#   139660813298832: TensorSpec(shape=(1, 1, 64, 32), dtype=tf.float32, name=None)
#   139660813299024: TensorSpec(shape=(32,), dtype=tf.float32, name=None)
#   139660813298256: TensorSpec(shape=(3, 3, 32, 32), dtype=tf.float32, name=None)
#   139660813299216: TensorSpec(shape=(32,), dtype=tf.float32, name=None)
#   139660813299408: TensorSpec(shape=(3, 3, 32, 32), dtype=tf.float32, name=None)
#   139660813299600: TensorSpec(shape=(32,), dtype=tf.float32, name=None)
#   139660813298448: TensorSpec(shape=(3, 3, 32, 32), dtype=tf.float32, name=None)
#   139660813299984: TensorSpec(shape=(32,), dtype=tf.float32, name=None)
#   139660813297872: TensorSpec(shape=(3, 3, 32, 32), dtype=tf.float32, name=None)
#   139660813294800: TensorSpec(shape=(1, 1, 64, 32), dtype=tf.float32, name=None)
#   139660813300176: TensorSpec(shape=(32,), dtype=tf.float32, name=None)
#   139660813296528: TensorSpec(shape=(32,), dtype=tf.float32, name=None)
#   139660813300752: TensorSpec(shape=(1, 1, 64, 64), dtype=tf.float32, name=None)
#   139660813299792: TensorSpec(shape=(64,), dtype=tf.float32, name=None)
#   139660813297104: TensorSpec(shape=(4,), dtype=tf.int64, name=None)
#   139660813297296: TensorSpec(shape=(4,), dtype=tf.int64, name=None)
#   139660813300944: TensorSpec(shape=(1, 1, 192, 128), dtype=tf.float32, name=None)
#   139660813301136: TensorSpec(shape=(128,), dtype=tf.float32, name=None)
#   139660813301328: TensorSpec(shape=(4, 2), dtype=tf.int32, name=None)
#   139660813300368: TensorSpec(shape=(3, 3, 128, 256), dtype=tf.float32, name=None)
#   139660813300560: TensorSpec(shape=(256,), dtype=tf.float32, name=None)
#   139660813301712: TensorSpec(shape=(1, 1, 256, 256), dtype=tf.float32, name=None)
#   139660813301904: TensorSpec(shape=(256,), dtype=tf.float32, name=None)
#   139660813302480: TensorSpec(shape=(4,), dtype=tf.int64, name=None)
#   139660813302288: TensorSpec(shape=(4,), dtype=tf.int64, name=None)
#   139660813302096: TensorSpec(shape=(1, 1, 128, 64), dtype=tf.float32, name=None)
#   139660813303440: TensorSpec(shape=(64,), dtype=tf.float32, name=None)
#   139660813303056: TensorSpec(shape=(3, 3, 64, 64), dtype=tf.float32, name=None)
#   139660541854928: TensorSpec(shape=(64,), dtype=tf.float32, name=None)
#   139660541853968: TensorSpec(shape=(3, 3, 64, 64), dtype=tf.float32, name=None)
#   139660541854736: TensorSpec(shape=(64,), dtype=tf.float32, name=None)
#   139660541855120: TensorSpec(shape=(3, 3, 64, 64), dtype=tf.float32, name=None)
#   139660541855504: TensorSpec(shape=(64,), dtype=tf.float32, name=None)
#   139660541854544: TensorSpec(shape=(3, 3, 64, 64), dtype=tf.float32, name=None)
#   139660813303248: TensorSpec(shape=(1, 1, 128, 64), dtype=tf.float32, name=None)
#   139660541855696: TensorSpec(shape=(64,), dtype=tf.float32, name=None)
#   139660813301520: TensorSpec(shape=(64,), dtype=tf.float32, name=None)
#   139660541856272: TensorSpec(shape=(1, 1, 128, 128), dtype=tf.float32, name=None)
#   139660541855312: TensorSpec(shape=(128,), dtype=tf.float32, name=None)
#   139660813302672: TensorSpec(shape=(4,), dtype=tf.int64, name=None)
#   139660813302864: TensorSpec(shape=(4,), dtype=tf.int64, name=None)
#   139660541856464: TensorSpec(shape=(1, 1, 384, 256), dtype=tf.float32, name=None)
#   139660541856656: TensorSpec(shape=(256,), dtype=tf.float32, name=None)
#   139660541855888: TensorSpec(shape=(1, 1, 256, 128), dtype=tf.float32, name=None)
#   139660541856848: TensorSpec(shape=(128,), dtype=tf.float32, name=None)
#   139660541857232: TensorSpec(shape=(1, 1, 512, 256), dtype=tf.float32, name=None)
#   139660541857424: TensorSpec(shape=(256,), dtype=tf.float32, name=None)
#   139660541856080: TensorSpec(shape=(1, 1, 256, 256), dtype=tf.float32, name=None)
#   139660541858192: TensorSpec(shape=(256,), dtype=tf.float32, name=None)
#   139660541858000: TensorSpec(shape=(1, 1, 128, 256), dtype=tf.float32, name=None)
#   139660541858384: TensorSpec(shape=(256,), dtype=tf.float32, name=None)
#   139660541859536: TensorSpec(shape=(3, 3, 1, 1), dtype=tf.float32, name=None)
#   139660541858960: TensorSpec(shape=(3, 3, 1, 1), dtype=tf.float32, name=None)
#   139660541859920: TensorSpec(shape=(3, 3, 1, 1), dtype=tf.float32, name=None)
#   139660541857808: TensorSpec(shape=(3, 3, 1, 1), dtype=tf.float32, name=None)
#   139660541857040: TensorSpec(shape=(3, 3, 1, 1), dtype=tf.float32, name=None)
#   139660541858768: TensorSpec(shape=(3, 3, 1, 1), dtype=tf.float32, name=None)
#   139660541860496: TensorSpec(shape=(3, 3, 1, 1), dtype=tf.float32, name=None)
#   139660541859344: TensorSpec(shape=(3, 3, 1, 1), dtype=tf.float32, name=None)
#   139660541861648: TensorSpec(shape=(3, 3, 1, 1), dtype=tf.float32, name=None)
#   139660541860304: TensorSpec(shape=(3, 3, 1, 1), dtype=tf.float32, name=None)
#   139660541859152: TensorSpec(shape=(3, 3, 1, 1), dtype=tf.float32, name=None)
#   139660541860688: TensorSpec(shape=(3, 3, 1, 1), dtype=tf.float32, name=None)
#   139660541859728: TensorSpec(shape=(3, 3, 1, 1), dtype=tf.float32, name=None)
#   139660541857616: TensorSpec(shape=(3, 3, 1, 1), dtype=tf.float32, name=None)
#   139660541862032: TensorSpec(shape=(3, 3, 1, 1), dtype=tf.float32, name=None)
#   139660541861264: TensorSpec(shape=(3, 3, 1, 1), dtype=tf.float32, name=None)
#   139660541861840: TensorSpec(shape=(3, 3, 1, 1), dtype=tf.float32, name=None)
#   139660541861072: TensorSpec(shape=(3, 3, 1, 1), dtype=tf.float32, name=None)
#   139660541861456: TensorSpec(shape=(3, 3, 1, 1), dtype=tf.float32, name=None)
#   139660541862224: TensorSpec(shape=(3, 3, 1, 1), dtype=tf.float32, name=None)
#   139660541862992: TensorSpec(shape=(3, 3, 1, 1), dtype=tf.float32, name=None)
#   139660541862608: TensorSpec(shape=(3, 3, 1, 1), dtype=tf.float32, name=None)
#   139660541862800: TensorSpec(shape=(3, 3, 1, 1), dtype=tf.float32, name=None)
#   139660541863184: TensorSpec(shape=(3, 3, 1, 1), dtype=tf.float32, name=None)
#   139660541863376: TensorSpec(shape=(3, 3, 1, 1), dtype=tf.float32, name=None)
#   139660541863760: TensorSpec(shape=(3, 3, 1, 1), dtype=tf.float32, name=None)
#   139660541863568: TensorSpec(shape=(3, 3, 1, 1), dtype=tf.float32, name=None)
#   139660541862416: TensorSpec(shape=(3, 3, 1, 1), dtype=tf.float32, name=None)
#   139660541863952: TensorSpec(shape=(3, 3, 1, 1), dtype=tf.float32, name=None)
#   139660541864336: TensorSpec(shape=(3, 3, 1, 1), dtype=tf.float32, name=None)
#   139660541864144: TensorSpec(shape=(3, 3, 1, 1), dtype=tf.float32, name=None)
#   139660541864528: TensorSpec(shape=(3, 3, 1, 1), dtype=tf.float32, name=None)
#   139660541864720: TensorSpec(shape=(3, 3, 1, 1), dtype=tf.float32, name=None)
#   139660541864912: TensorSpec(shape=(3, 3, 1, 1), dtype=tf.float32, name=None)
#   139660541865104: TensorSpec(shape=(3, 3, 1, 1), dtype=tf.float32, name=None)
#   139660541865296: TensorSpec(shape=(3, 3, 1, 1), dtype=tf.float32, name=None)
#   139660541865488: TensorSpec(shape=(3, 3, 1, 1), dtype=tf.float32, name=None)
#   139660541865680: TensorSpec(shape=(3, 3, 1, 1), dtype=tf.float32, name=None)
#   139660541865872: TensorSpec(shape=(3, 3, 1, 1), dtype=tf.float32, name=None)
#   139660541866064: TensorSpec(shape=(3, 3, 1, 1), dtype=tf.float32, name=None)
#   139660541866256: TensorSpec(shape=(3, 3, 1, 1), dtype=tf.float32, name=None)
#   139660541866448: TensorSpec(shape=(3, 3, 1, 1), dtype=tf.float32, name=None)
#   139660541866640: TensorSpec(shape=(3, 3, 1, 1), dtype=tf.float32, name=None)
#   139660541866832: TensorSpec(shape=(3, 3, 1, 1), dtype=tf.float32, name=None)
#   139660541867024: TensorSpec(shape=(3, 3, 1, 1), dtype=tf.float32, name=None)
#   139660541867216: TensorSpec(shape=(3, 3, 1, 1), dtype=tf.float32, name=None)
#   139660541867408: TensorSpec(shape=(3, 3, 1, 1), dtype=tf.float32, name=None)
#   139660541867600: TensorSpec(shape=(3, 3, 1, 1), dtype=tf.float32, name=None)
#   139660541867792: TensorSpec(shape=(3, 3, 1, 1), dtype=tf.float32, name=None)
#   139660541867984: TensorSpec(shape=(3, 3, 1, 1), dtype=tf.float32, name=None)
#   139660541868176: TensorSpec(shape=(3, 3, 1, 1), dtype=tf.float32, name=None)
#   139660541868368: TensorSpec(shape=(3, 3, 1, 1), dtype=tf.float32, name=None)
#   139660541868560: TensorSpec(shape=(3, 3, 1, 1), dtype=tf.float32, name=None)
#   139660541868752: TensorSpec(shape=(3, 3, 1, 1), dtype=tf.float32, name=None)
#   139660541868944: TensorSpec(shape=(3, 3, 1, 1), dtype=tf.float32, name=None)
#   139660541869136: TensorSpec(shape=(3, 3, 1, 1), dtype=tf.float32, name=None)
#   139660541869328: TensorSpec(shape=(3, 3, 1, 1), dtype=tf.float32, name=None)
#   139660541869520: TensorSpec(shape=(3, 3, 1, 1), dtype=tf.float32, name=None)
#   139660541869712: TensorSpec(shape=(3, 3, 1, 1), dtype=tf.float32, name=None)
#   139660541869904: TensorSpec(shape=(3, 3, 1, 1), dtype=tf.float32, name=None)
#   139660539330640: TensorSpec(shape=(3, 3, 1, 1), dtype=tf.float32, name=None)
#   139660539330832: TensorSpec(shape=(3, 3, 1, 1), dtype=tf.float32, name=None)
#   139660539331024: TensorSpec(shape=(3, 3, 1, 1), dtype=tf.float32, name=None)
#   139660539331216: TensorSpec(shape=(3, 3, 1, 1), dtype=tf.float32, name=None)
#   139660539331408: TensorSpec(shape=(3, 3, 1, 1), dtype=tf.float32, name=None)
#   139660539331600: TensorSpec(shape=(3, 3, 1, 1), dtype=tf.float32, name=None)
#   139660539331792: TensorSpec(shape=(3, 3, 1, 1), dtype=tf.float32, name=None)
#   139660539331984: TensorSpec(shape=(3, 3, 1, 1), dtype=tf.float32, name=None)
#   139660539332176: TensorSpec(shape=(3, 3, 1, 1), dtype=tf.float32, name=None)
#   139660539332368: TensorSpec(shape=(3, 3, 1, 1), dtype=tf.float32, name=None)
#   139660539332560: TensorSpec(shape=(3, 3, 1, 1), dtype=tf.float32, name=None)
#   139660539332752: TensorSpec(shape=(3, 3, 1, 1), dtype=tf.float32, name=None)
#   139660539332944: TensorSpec(shape=(3, 3, 1, 1), dtype=tf.float32, name=None)
#   139660539333136: TensorSpec(shape=(3, 3, 1, 1), dtype=tf.float32, name=None)
#   139660539333328: TensorSpec(shape=(3, 3, 1, 1), dtype=tf.float32, name=None)
#   139660539333520: TensorSpec(shape=(3, 3, 1, 1), dtype=tf.float32, name=None)
#   139660539333712: TensorSpec(shape=(3, 3, 1, 1), dtype=tf.float32, name=None)
#   139660539333904: TensorSpec(shape=(3, 3, 1, 1), dtype=tf.float32, name=None)
#   139660539334096: TensorSpec(shape=(3, 3, 1, 1), dtype=tf.float32, name=None)
#   139660539334288: TensorSpec(shape=(3, 3, 1, 1), dtype=tf.float32, name=None)
#   139660539334480: TensorSpec(shape=(3, 3, 1, 1), dtype=tf.float32, name=None)
#   139660539334672: TensorSpec(shape=(3, 3, 1, 1), dtype=tf.float32, name=None)
#   139660539334864: TensorSpec(shape=(3, 3, 1, 1), dtype=tf.float32, name=None)
#   139660539335056: TensorSpec(shape=(3, 3, 1, 1), dtype=tf.float32, name=None)
#   139660539335248: TensorSpec(shape=(3, 3, 1, 1), dtype=tf.float32, name=None)
#   139660539335440: TensorSpec(shape=(3, 3, 1, 1), dtype=tf.float32, name=None)
#   139660539335632: TensorSpec(shape=(3, 3, 1, 1), dtype=tf.float32, name=None)
#   139660539335824: TensorSpec(shape=(3, 3, 1, 1), dtype=tf.float32, name=None)
#   139660539336016: TensorSpec(shape=(3, 3, 1, 1), dtype=tf.float32, name=None)
#   139660539336208: TensorSpec(shape=(3, 3, 1, 1), dtype=tf.float32, name=None)
#   139660539336400: TensorSpec(shape=(3, 3, 1, 1), dtype=tf.float32, name=None)
#   139660539336592: TensorSpec(shape=(3, 3, 1, 1), dtype=tf.float32, name=None)
#   139660539336784: TensorSpec(shape=(3, 3, 1, 1), dtype=tf.float32, name=None)
#   139660539336976: TensorSpec(shape=(3, 3, 1, 1), dtype=tf.float32, name=None)
#   139660539337168: TensorSpec(shape=(3, 3, 1, 1), dtype=tf.float32, name=None)
#   139660539337360: TensorSpec(shape=(3, 3, 1, 1), dtype=tf.float32, name=None)
#   139660539337552: TensorSpec(shape=(3, 3, 1, 1), dtype=tf.float32, name=None)
#   139660539337744: TensorSpec(shape=(3, 3, 1, 1), dtype=tf.float32, name=None)
#   139660539337936: TensorSpec(shape=(3, 3, 1, 1), dtype=tf.float32, name=None)
#   139660539338128: TensorSpec(shape=(3, 3, 1, 1), dtype=tf.float32, name=None)
#   139660539338320: TensorSpec(shape=(3, 3, 1, 1), dtype=tf.float32, name=None)
#   139660539338512: TensorSpec(shape=(3, 3, 1, 1), dtype=tf.float32, name=None)
#   139660539338704: TensorSpec(shape=(3, 3, 1, 1), dtype=tf.float32, name=None)
#   139660539338896: TensorSpec(shape=(3, 3, 1, 1), dtype=tf.float32, name=None)
#   139660539339088: TensorSpec(shape=(3, 3, 1, 1), dtype=tf.float32, name=None)
#   139660539339280: TensorSpec(shape=(3, 3, 1, 1), dtype=tf.float32, name=None)
#   139660539339472: TensorSpec(shape=(3, 3, 1, 1), dtype=tf.float32, name=None)
#   139660539339664: TensorSpec(shape=(3, 3, 1, 1), dtype=tf.float32, name=None)
#   139660539339856: TensorSpec(shape=(3, 3, 1, 1), dtype=tf.float32, name=None)
#   139660539340048: TensorSpec(shape=(3, 3, 1, 1), dtype=tf.float32, name=None)
#   139660539340240: TensorSpec(shape=(3, 3, 1, 1), dtype=tf.float32, name=None)
#   139660539340432: TensorSpec(shape=(3, 3, 1, 1), dtype=tf.float32, name=None)
#   139660539340624: TensorSpec(shape=(3, 3, 1, 1), dtype=tf.float32, name=None)
#   139660539340816: TensorSpec(shape=(3, 3, 1, 1), dtype=tf.float32, name=None)
#   139660539341008: TensorSpec(shape=(3, 3, 1, 1), dtype=tf.float32, name=None)
#   139660539341200: TensorSpec(shape=(3, 3, 1, 1), dtype=tf.float32, name=None)
#   139660539341392: TensorSpec(shape=(3, 3, 1, 1), dtype=tf.float32, name=None)
#   139660539341584: TensorSpec(shape=(3, 3, 1, 1), dtype=tf.float32, name=None)
#   139660539341776: TensorSpec(shape=(3, 3, 1, 1), dtype=tf.float32, name=None)
#   139660539341968: TensorSpec(shape=(3, 3, 1, 1), dtype=tf.float32, name=None)
#   139660539342160: TensorSpec(shape=(3, 3, 1, 1), dtype=tf.float32, name=None)
#   139660539342352: TensorSpec(shape=(3, 3, 1, 1), dtype=tf.float32, name=None)
#   139660539342544: TensorSpec(shape=(3, 3, 1, 1), dtype=tf.float32, name=None)
#   139660539342736: TensorSpec(shape=(3, 3, 1, 1), dtype=tf.float32, name=None)
#   139660539342928: TensorSpec(shape=(3, 3, 1, 1), dtype=tf.float32, name=None)
#   139660539343120: TensorSpec(shape=(3, 3, 1, 1), dtype=tf.float32, name=None)
#   139660539343312: TensorSpec(shape=(3, 3, 1, 1), dtype=tf.float32, name=None)
#   139660539343504: TensorSpec(shape=(3, 3, 1, 1), dtype=tf.float32, name=None)
#   139660541858576: TensorSpec(shape=(128,), dtype=tf.float32, name=None)
#   139660541860880: TensorSpec(shape=(1, 1, 128, 128), dtype=tf.float32, name=None)
#   139660539343888: TensorSpec(shape=(128,), dtype=tf.float32, name=None)
#   139660539344272: TensorSpec(shape=(1, 1, 128, 256), dtype=tf.float32, name=None)
#   139660539345808: TensorSpec(shape=(256,), dtype=tf.float32, name=None)
#   139660539345040: TensorSpec(shape=(1, 1, 256, 128), dtype=tf.float32, name=None)
#   139660539345424: TensorSpec(shape=(128,), dtype=tf.float32, name=None)
#   139660539346000: TensorSpec(shape=(1, 1, 256, 256), dtype=tf.float32, name=None)
#   139660539344848: TensorSpec(shape=(256,), dtype=tf.float32, name=None)
#   139660539343696: TensorSpec(shape=(1, 1, 384, 128), dtype=tf.float32, name=None)
#   139660539346384: TensorSpec(shape=(128,), dtype=tf.float32, name=None)
#   139660539346192: TensorSpec(shape=(4,), dtype=tf.int64, name=None)
#   139660533530896: TensorSpec(shape=(4,), dtype=tf.int64, name=None)
#   139660539346576: TensorSpec(shape=(1, 1, 64, 32), dtype=tf.float32, name=None)
#   139660539344656: TensorSpec(shape=(32,), dtype=tf.float32, name=None)
#   139660533532048: TensorSpec(shape=(3, 3, 32, 32), dtype=tf.float32, name=None)
#   139660533532240: TensorSpec(shape=(32,), dtype=tf.float32, name=None)
#   139660533532432: TensorSpec(shape=(3, 3, 32, 32), dtype=tf.float32, name=None)
#   139660533532624: TensorSpec(shape=(32,), dtype=tf.float32, name=None)
#   139660533531664: TensorSpec(shape=(3, 3, 32, 32), dtype=tf.float32, name=None)
#   139660533533008: TensorSpec(shape=(32,), dtype=tf.float32, name=None)
#   139660533531472: TensorSpec(shape=(3, 3, 32, 32), dtype=tf.float32, name=None)
#   139660539344464: TensorSpec(shape=(1, 1, 64, 32), dtype=tf.float32, name=None)
#   139660533533200: TensorSpec(shape=(32,), dtype=tf.float32, name=None)
#   139660539345232: TensorSpec(shape=(32,), dtype=tf.float32, name=None)
#   139660533533776: TensorSpec(shape=(1, 1, 64, 64), dtype=tf.float32, name=None)
#   139660533532816: TensorSpec(shape=(64,), dtype=tf.float32, name=None)
#   139660539346768: TensorSpec(shape=(4,), dtype=tf.int64, name=None)
#   139660539345616: TensorSpec(shape=(4,), dtype=tf.int64, name=None)
#   139660533533968: TensorSpec(shape=(1, 1, 192, 128), dtype=tf.float32, name=None)
#   139660533534160: TensorSpec(shape=(128,), dtype=tf.float32, name=None)
#   139660533534544: TensorSpec(shape=(1, 1, 256, 64), dtype=tf.float32, name=None)
#   139660533533392: TensorSpec(shape=(64,), dtype=tf.float32, name=None)
#   139660533534928: TensorSpec(shape=(4,), dtype=tf.int64, name=None)
#   139660533534736: TensorSpec(shape=(4,), dtype=tf.int64, name=None)
#   139660533536848: TensorSpec(shape=(1, 1, 32, 16), dtype=tf.float32, name=None)
#   139660533537040: TensorSpec(shape=(16,), dtype=tf.float32, name=None)
#   139660533536272: TensorSpec(shape=(3, 3, 16, 16), dtype=tf.float32, name=None)
#   139660533537232: TensorSpec(shape=(16,), dtype=tf.float32, name=None)
#   139660533537424: TensorSpec(shape=(3, 3, 16, 16), dtype=tf.float32, name=None)
#   139660533537616: TensorSpec(shape=(16,), dtype=tf.float32, name=None)
#   139660533536464: TensorSpec(shape=(3, 3, 16, 16), dtype=tf.float32, name=None)
#   139660533538000: TensorSpec(shape=(16,), dtype=tf.float32, name=None)
#   139660859119888: TensorSpec(shape=(3, 3, 16, 16), dtype=tf.float32, name=None)
#   139660533533584: TensorSpec(shape=(1, 1, 32, 16), dtype=tf.float32, name=None)
#   139660846762128: TensorSpec(shape=(16,), dtype=tf.float32, name=None)
#   139660533534352: TensorSpec(shape=(16,), dtype=tf.float32, name=None)
#   139660846764432: TensorSpec(shape=(1, 1, 32, 32), dtype=tf.float32, name=None)
#   139660846774032: TensorSpec(shape=(32,), dtype=tf.float32, name=None)
#   139660533535120: TensorSpec(shape=(4,), dtype=tf.int64, name=None)
#   139660533535312: TensorSpec(shape=(4,), dtype=tf.int64, name=None)
#   139660846761168: TensorSpec(shape=(1, 1, 96, 64), dtype=tf.float32, name=None)
#   139660846766352: TensorSpec(shape=(64,), dtype=tf.float32, name=None)
#   139660846771152: TensorSpec(shape=(4, 2), dtype=tf.int32, name=None)
#   139660846773264: TensorSpec(shape=(3, 3, 64, 64), dtype=tf.float32, name=None)
#   139660846774224: TensorSpec(shape=(64,), dtype=tf.float32, name=None)
#   139660533538576: TensorSpec(shape=(1, 1, 192, 128), dtype=tf.float32, name=None)
#   139660533537808: TensorSpec(shape=(128,), dtype=tf.float32, name=None)
#   139660533540880: TensorSpec(shape=(4,), dtype=tf.int64, name=None)
#   139660533541648: TensorSpec(shape=(4,), dtype=tf.int64, name=None)
#   139660533540112: TensorSpec(shape=(1, 1, 64, 32), dtype=tf.float32, name=None)
#   139660533543760: TensorSpec(shape=(32,), dtype=tf.float32, name=None)
#   139660533544528: TensorSpec(shape=(3, 3, 32, 32), dtype=tf.float32, name=None)
#   139660533543952: TensorSpec(shape=(32,), dtype=tf.float32, name=None)
#   139660533546640: TensorSpec(shape=(3, 3, 32, 32), dtype=tf.float32, name=None)
#   139660533545296: TensorSpec(shape=(32,), dtype=tf.float32, name=None)
#   139660533542608: TensorSpec(shape=(3, 3, 32, 32), dtype=tf.float32, name=None)
#   139660533546064: TensorSpec(shape=(32,), dtype=tf.float32, name=None)
#   139660533545872: TensorSpec(shape=(3, 3, 32, 32), dtype=tf.float32, name=None)
#   139660533543184: TensorSpec(shape=(1, 1, 64, 32), dtype=tf.float32, name=None)
#   139660533540304: TensorSpec(shape=(32,), dtype=tf.float32, name=None)
#   139660533541456: TensorSpec(shape=(32,), dtype=tf.float32, name=None)
#   139660533539152: TensorSpec(shape=(1, 1, 64, 64), dtype=tf.float32, name=None)
#   139660533540496: TensorSpec(shape=(64,), dtype=tf.float32, name=None)
#   139660533539920: TensorSpec(shape=(4,), dtype=tf.int64, name=None)
#   139660533539344: TensorSpec(shape=(4,), dtype=tf.int64, name=None)
#   139660533540688: TensorSpec(shape=(1, 1, 192, 128), dtype=tf.float32, name=None)
#   139660533546832: TensorSpec(shape=(128,), dtype=tf.float32, name=None)
#   139660533538192: TensorSpec(shape=(4, 2), dtype=tf.int32, name=None)
#   139660533545104: TensorSpec(shape=(3, 3, 128, 128), dtype=tf.float32, name=None)
#   139660533544720: TensorSpec(shape=(128,), dtype=tf.float32, name=None)
#   139660533545680: TensorSpec(shape=(1, 1, 384, 256), dtype=tf.float32, name=None)
#   139660813877328: TensorSpec(shape=(256,), dtype=tf.float32, name=None)
#   139660813878480: TensorSpec(shape=(4,), dtype=tf.int64, name=None)
#   139660813878672: TensorSpec(shape=(4,), dtype=tf.int64, name=None)
#   139660813879824: TensorSpec(shape=(3, 3, 128, 64), dtype=tf.float32, name=None)
#   139660813881552: TensorSpec(shape=(64,), dtype=tf.float32, name=None)
#   139660813878864: TensorSpec(shape=(3, 3, 64, 128), dtype=tf.float32, name=None)
#   139660813881168: TensorSpec(shape=(128,), dtype=tf.float32, name=None)
#   139660813882512: TensorSpec(shape=(1, 1, 128, 256), dtype=tf.float32, name=None)
#   139660813883280: TensorSpec(shape=(256,), dtype=tf.float32, name=None)
#   139660813877712: TensorSpec(shape=(3, 3, 1, 1), dtype=tf.float32, name=None)
#   139660813884816: TensorSpec(shape=(3, 3, 1, 1), dtype=tf.float32, name=None)
#   139660813884048: TensorSpec(shape=(3, 3, 1, 1), dtype=tf.float32, name=None)
#   139660813885584: TensorSpec(shape=(3, 3, 1, 1), dtype=tf.float32, name=None)
#   139660813885968: TensorSpec(shape=(3, 3, 1, 1), dtype=tf.float32, name=None)
#   139660813885776: TensorSpec(shape=(3, 3, 1, 1), dtype=tf.float32, name=None)
#   139660813884240: TensorSpec(shape=(3, 3, 1, 1), dtype=tf.float32, name=None)
#   139660813885200: TensorSpec(shape=(3, 3, 1, 1), dtype=tf.float32, name=None)
#   139660813882128: TensorSpec(shape=(3, 3, 1, 1), dtype=tf.float32, name=None)
#   139660813886160: TensorSpec(shape=(3, 3, 1, 1), dtype=tf.float32, name=None)
#   139660813883856: TensorSpec(shape=(3, 3, 1, 1), dtype=tf.float32, name=None)
#   139660813885008: TensorSpec(shape=(3, 3, 1, 1), dtype=tf.float32, name=None)
#   139660813886352: TensorSpec(shape=(3, 3, 1, 1), dtype=tf.float32, name=None)
#   139660813886544: TensorSpec(shape=(3, 3, 1, 1), dtype=tf.float32, name=None)
#   139660813886736: TensorSpec(shape=(3, 3, 1, 1), dtype=tf.float32, name=None)
#   139660813886928: TensorSpec(shape=(3, 3, 1, 1), dtype=tf.float32, name=None)
#   139660813887120: TensorSpec(shape=(3, 3, 1, 1), dtype=tf.float32, name=None)
#   139660813887312: TensorSpec(shape=(3, 3, 1, 1), dtype=tf.float32, name=None)
#   139660813887504: TensorSpec(shape=(3, 3, 1, 1), dtype=tf.float32, name=None)
#   139660813887696: TensorSpec(shape=(3, 3, 1, 1), dtype=tf.float32, name=None)
#   139660813887888: TensorSpec(shape=(3, 3, 1, 1), dtype=tf.float32, name=None)
#   139660813888080: TensorSpec(shape=(3, 3, 1, 1), dtype=tf.float32, name=None)
#   139660813888272: TensorSpec(shape=(3, 3, 1, 1), dtype=tf.float32, name=None)
#   139660813888464: TensorSpec(shape=(3, 3, 1, 1), dtype=tf.float32, name=None)
#   139660813888656: TensorSpec(shape=(3, 3, 1, 1), dtype=tf.float32, name=None)
#   139660813888848: TensorSpec(shape=(3, 3, 1, 1), dtype=tf.float32, name=None)
#   139660813889040: TensorSpec(shape=(3, 3, 1, 1), dtype=tf.float32, name=None)
#   139660813889232: TensorSpec(shape=(3, 3, 1, 1), dtype=tf.float32, name=None)
#   139660813889424: TensorSpec(shape=(3, 3, 1, 1), dtype=tf.float32, name=None)
#   139660813889616: TensorSpec(shape=(3, 3, 1, 1), dtype=tf.float32, name=None)
#   139660813889808: TensorSpec(shape=(3, 3, 1, 1), dtype=tf.float32, name=None)
#   139660813890000: TensorSpec(shape=(3, 3, 1, 1), dtype=tf.float32, name=None)
#   139660813890192: TensorSpec(shape=(3, 3, 1, 1), dtype=tf.float32, name=None)
#   139660813890384: TensorSpec(shape=(3, 3, 1, 1), dtype=tf.float32, name=None)
#   139660813890576: TensorSpec(shape=(3, 3, 1, 1), dtype=tf.float32, name=None)
#   139660813890768: TensorSpec(shape=(3, 3, 1, 1), dtype=tf.float32, name=None)
#   139660813890960: TensorSpec(shape=(3, 3, 1, 1), dtype=tf.float32, name=None)
#   139660813891152: TensorSpec(shape=(3, 3, 1, 1), dtype=tf.float32, name=None)
#   139660813891344: TensorSpec(shape=(3, 3, 1, 1), dtype=tf.float32, name=None)
#   139660813891536: TensorSpec(shape=(3, 3, 1, 1), dtype=tf.float32, name=None)
#   139660813891728: TensorSpec(shape=(3, 3, 1, 1), dtype=tf.float32, name=None)
#   139660813891920: TensorSpec(shape=(3, 3, 1, 1), dtype=tf.float32, name=None)
#   139660813892112: TensorSpec(shape=(3, 3, 1, 1), dtype=tf.float32, name=None)
#   139660813892304: TensorSpec(shape=(3, 3, 1, 1), dtype=tf.float32, name=None)
#   139660813892496: TensorSpec(shape=(3, 3, 1, 1), dtype=tf.float32, name=None)
#   139660813892688: TensorSpec(shape=(3, 3, 1, 1), dtype=tf.float32, name=None)
#   139660813892880: TensorSpec(shape=(3, 3, 1, 1), dtype=tf.float32, name=None)
#   139660813893072: TensorSpec(shape=(3, 3, 1, 1), dtype=tf.float32, name=None)
#   139660813893264: TensorSpec(shape=(3, 3, 1, 1), dtype=tf.float32, name=None)
#   139660813893456: TensorSpec(shape=(3, 3, 1, 1), dtype=tf.float32, name=None)
#   139660813880400: TensorSpec(shape=(3, 3, 1, 1), dtype=tf.float32, name=None)
#   139660813880784: TensorSpec(shape=(3, 3, 1, 1), dtype=tf.float32, name=None)
#   139660813883472: TensorSpec(shape=(3, 3, 1, 1), dtype=tf.float32, name=None)
#   139660813882320: TensorSpec(shape=(3, 3, 1, 1), dtype=tf.float32, name=None)
#   139660813882896: TensorSpec(shape=(3, 3, 1, 1), dtype=tf.float32, name=None)
#   139660813881360: TensorSpec(shape=(3, 3, 1, 1), dtype=tf.float32, name=None)
#   139660813884624: TensorSpec(shape=(3, 3, 1, 1), dtype=tf.float32, name=None)
#   139660813883088: TensorSpec(shape=(3, 3, 1, 1), dtype=tf.float32, name=None)
#   139660813885392: TensorSpec(shape=(3, 3, 1, 1), dtype=tf.float32, name=None)
#   139660813883664: TensorSpec(shape=(3, 3, 1, 1), dtype=tf.float32, name=None)
#   139660531335248: TensorSpec(shape=(3, 3, 1, 1), dtype=tf.float32, name=None)
#   139660531335440: TensorSpec(shape=(3, 3, 1, 1), dtype=tf.float32, name=None)
#   139660531335632: TensorSpec(shape=(3, 3, 1, 1), dtype=tf.float32, name=None)
#   139660531335824: TensorSpec(shape=(3, 3, 1, 1), dtype=tf.float32, name=None)
#   139660531336016: TensorSpec(shape=(3, 3, 1, 1), dtype=tf.float32, name=None)
#   139660531336208: TensorSpec(shape=(3, 3, 1, 1), dtype=tf.float32, name=None)
#   139660531336400: TensorSpec(shape=(3, 3, 1, 1), dtype=tf.float32, name=None)
#   139660531336592: TensorSpec(shape=(3, 3, 1, 1), dtype=tf.float32, name=None)
#   139660531336784: TensorSpec(shape=(3, 3, 1, 1), dtype=tf.float32, name=None)
#   139660531336976: TensorSpec(shape=(3, 3, 1, 1), dtype=tf.float32, name=None)
#   139660531337168: TensorSpec(shape=(3, 3, 1, 1), dtype=tf.float32, name=None)
#   139660531337360: TensorSpec(shape=(3, 3, 1, 1), dtype=tf.float32, name=None)
#   139660531337552: TensorSpec(shape=(3, 3, 1, 1), dtype=tf.float32, name=None)
#   139660531337744: TensorSpec(shape=(3, 3, 1, 1), dtype=tf.float32, name=None)
#   139660531337936: TensorSpec(shape=(3, 3, 1, 1), dtype=tf.float32, name=None)
#   139660531338128: TensorSpec(shape=(3, 3, 1, 1), dtype=tf.float32, name=None)
#   139660531338320: TensorSpec(shape=(3, 3, 1, 1), dtype=tf.float32, name=None)
#   139660531338512: TensorSpec(shape=(3, 3, 1, 1), dtype=tf.float32, name=None)
#   139660531338704: TensorSpec(shape=(3, 3, 1, 1), dtype=tf.float32, name=None)
#   139660531338896: TensorSpec(shape=(3, 3, 1, 1), dtype=tf.float32, name=None)
#   139660531339088: TensorSpec(shape=(3, 3, 1, 1), dtype=tf.float32, name=None)
#   139660531339280: TensorSpec(shape=(3, 3, 1, 1), dtype=tf.float32, name=None)
#   139660531339472: TensorSpec(shape=(3, 3, 1, 1), dtype=tf.float32, name=None)
#   139660531339664: TensorSpec(shape=(3, 3, 1, 1), dtype=tf.float32, name=None)
#   139660531339856: TensorSpec(shape=(3, 3, 1, 1), dtype=tf.float32, name=None)
#   139660531340048: TensorSpec(shape=(3, 3, 1, 1), dtype=tf.float32, name=None)
#   139660531340240: TensorSpec(shape=(3, 3, 1, 1), dtype=tf.float32, name=None)
#   139660531340432: TensorSpec(shape=(3, 3, 1, 1), dtype=tf.float32, name=None)
#   139660531340624: TensorSpec(shape=(3, 3, 1, 1), dtype=tf.float32, name=None)
#   139660531340816: TensorSpec(shape=(3, 3, 1, 1), dtype=tf.float32, name=None)
#   139660531341008: TensorSpec(shape=(3, 3, 1, 1), dtype=tf.float32, name=None)
#   139660531341200: TensorSpec(shape=(3, 3, 1, 1), dtype=tf.float32, name=None)
#   139660531341392: TensorSpec(shape=(3, 3, 1, 1), dtype=tf.float32, name=None)
#   139660531341584: TensorSpec(shape=(3, 3, 1, 1), dtype=tf.float32, name=None)
#   139660531341776: TensorSpec(shape=(3, 3, 1, 1), dtype=tf.float32, name=None)
#   139660531341968: TensorSpec(shape=(3, 3, 1, 1), dtype=tf.float32, name=None)
#   139660531342160: TensorSpec(shape=(3, 3, 1, 1), dtype=tf.float32, name=None)
#   139660531342352: TensorSpec(shape=(3, 3, 1, 1), dtype=tf.float32, name=None)
#   139660531342544: TensorSpec(shape=(3, 3, 1, 1), dtype=tf.float32, name=None)
#   139660531342736: TensorSpec(shape=(3, 3, 1, 1), dtype=tf.float32, name=None)
#   139660531342928: TensorSpec(shape=(3, 3, 1, 1), dtype=tf.float32, name=None)
#   139660531343120: TensorSpec(shape=(3, 3, 1, 1), dtype=tf.float32, name=None)
#   139660531343312: TensorSpec(shape=(3, 3, 1, 1), dtype=tf.float32, name=None)
#   139660531343504: TensorSpec(shape=(3, 3, 1, 1), dtype=tf.float32, name=None)
#   139660531343696: TensorSpec(shape=(3, 3, 1, 1), dtype=tf.float32, name=None)
#   139660531343888: TensorSpec(shape=(3, 3, 1, 1), dtype=tf.float32, name=None)
#   139660531344080: TensorSpec(shape=(3, 3, 1, 1), dtype=tf.float32, name=None)
#   139660531344272: TensorSpec(shape=(3, 3, 1, 1), dtype=tf.float32, name=None)
#   139660531344464: TensorSpec(shape=(3, 3, 1, 1), dtype=tf.float32, name=None)
#   139660531344656: TensorSpec(shape=(3, 3, 1, 1), dtype=tf.float32, name=None)
#   139660531344848: TensorSpec(shape=(3, 3, 1, 1), dtype=tf.float32, name=None)
#   139660531345040: TensorSpec(shape=(3, 3, 1, 1), dtype=tf.float32, name=None)
#   139660531345232: TensorSpec(shape=(3, 3, 1, 1), dtype=tf.float32, name=None)
#   139660531345424: TensorSpec(shape=(3, 3, 1, 1), dtype=tf.float32, name=None)
#   139660531345616: TensorSpec(shape=(3, 3, 1, 1), dtype=tf.float32, name=None)
#   139660531345808: TensorSpec(shape=(3, 3, 1, 1), dtype=tf.float32, name=None)
#   139660531346000: TensorSpec(shape=(3, 3, 1, 1), dtype=tf.float32, name=None)
#   139660531346192: TensorSpec(shape=(3, 3, 1, 1), dtype=tf.float32, name=None)
#   139660531346384: TensorSpec(shape=(3, 3, 1, 1), dtype=tf.float32, name=None)
#   139660531346576: TensorSpec(shape=(3, 3, 1, 1), dtype=tf.float32, name=None)
#   139660531346768: TensorSpec(shape=(3, 3, 1, 1), dtype=tf.float32, name=None)
#   139660531346960: TensorSpec(shape=(3, 3, 1, 1), dtype=tf.float32, name=None)
#   139660531347152: TensorSpec(shape=(3, 3, 1, 1), dtype=tf.float32, name=None)
#   139660531347344: TensorSpec(shape=(3, 3, 1, 1), dtype=tf.float32, name=None)
#   139660531347536: TensorSpec(shape=(3, 3, 1, 1), dtype=tf.float32, name=None)
#   139660531347728: TensorSpec(shape=(3, 3, 1, 1), dtype=tf.float32, name=None)
#   139660531347920: TensorSpec(shape=(3, 3, 1, 1), dtype=tf.float32, name=None)
#   139660531348112: TensorSpec(shape=(3, 3, 1, 1), dtype=tf.float32, name=None)
#   139660813884432: TensorSpec(shape=(128,), dtype=tf.float32, name=None)
#   139660813882704: TensorSpec(shape=(1, 1, 128, 128), dtype=tf.float32, name=None)
#   139660531350992: TensorSpec(shape=(128,), dtype=tf.float32, name=None)
#   139660531349072: TensorSpec(shape=(1, 1, 128, 256), dtype=tf.float32, name=None)
#   139660531348880: TensorSpec(shape=(256,), dtype=tf.float32, name=None)
#   139660531351376: TensorSpec(shape=(1, 1, 256, 128), dtype=tf.float32, name=None)
#   139660531349456: TensorSpec(shape=(128,), dtype=tf.float32, name=None)
#   139660846766736: TensorSpec(shape=(3, 3, 64, 1), dtype=tf.float32, name=None)
#   139660813879056: TensorSpec(shape=(4,), dtype=tf.int64, name=None)
#   139660813879248: TensorSpec(shape=(4,), dtype=tf.int64, name=None)
#   139660846766928: TensorSpec(shape=(64,), dtype=tf.float32, name=None)
#   139660531349264: TensorSpec(shape=(1, 1, 384, 256), dtype=tf.float32, name=None)
#   139660531348304: TensorSpec(shape=(256,), dtype=tf.float32, name=None)
#   139660533535888: TensorSpec(shape=(1, 1, 64, 80), dtype=tf.float32, name=None)
#   139660533538384: TensorSpec(shape=(80,), dtype=tf.float32, name=None)
#   139660531350224: TensorSpec(shape=(3, 3, 256, 1), dtype=tf.float32, name=None)
#   139660533546256: TensorSpec(shape=(3, 3, 128, 1), dtype=tf.float32, name=None)
#   139660531350800: TensorSpec(shape=(256,), dtype=tf.float32, name=None)
#   139660533541072: TensorSpec(shape=(128,), dtype=tf.float32, name=None)
#   139660531348496: TensorSpec(shape=(1, 1, 256, 80), dtype=tf.float32, name=None)
#   139660533542992: TensorSpec(shape=(1, 1, 128, 80), dtype=tf.float32, name=None)
#   139660533539728: TensorSpec(shape=(3, 3, 80, 1), dtype=tf.float32, name=None)
#   139660531349648: TensorSpec(shape=(80,), dtype=tf.float32, name=None)
#   139660533542800: TensorSpec(shape=(80,), dtype=tf.float32, name=None)
#   139660533538960: TensorSpec(shape=(80,), dtype=tf.float32, name=None)
#   139660531350416: TensorSpec(shape=(3, 3, 256, 16), dtype=tf.float32, name=None)
#   139660533544144: TensorSpec(shape=(3, 3, 128, 16), dtype=tf.float32, name=None)
#   139660846767696: TensorSpec(shape=(3, 3, 64, 16), dtype=tf.float32, name=None)
#   139660531350608: TensorSpec(shape=(16,), dtype=tf.float32, name=None)
#   139660533544912: TensorSpec(shape=(16,), dtype=tf.float32, name=None)
#   139660846767312: TensorSpec(shape=(16,), dtype=tf.float32, name=None)
#   139660528992720: TensorSpec(shape=(3, 3, 80, 1), dtype=tf.float32, name=None)
#   139660813878096: TensorSpec(shape=(3, 3, 80, 1), dtype=tf.float32, name=None)
#   139660528992912: TensorSpec(shape=(80,), dtype=tf.float32, name=None)
#   139660813878288: TensorSpec(shape=(80,), dtype=tf.float32, name=None)
#   139660531350032: TensorSpec(shape=(3, 3, 16, 16), dtype=tf.float32, name=None)
#   139660533543376: TensorSpec(shape=(3, 3, 16, 16), dtype=tf.float32, name=None)
#   139660846765584: TensorSpec(shape=(3, 3, 16, 16), dtype=tf.float32, name=None)
#   139660533543568: TensorSpec(shape=(1, 1, 80, 80), dtype=tf.float32, name=None)
#   139660531351184: TensorSpec(shape=(16,), dtype=tf.float32, name=None)
#   139660533546448: TensorSpec(shape=(16,), dtype=tf.float32, name=None)
#   139660846765392: TensorSpec(shape=(16,), dtype=tf.float32, name=None)
#   139660533541264: TensorSpec(shape=(80,), dtype=tf.float32, name=None)
#   139660528996176: TensorSpec(shape=(1, 1, 80, 80), dtype=tf.float32, name=None)
#   139660813880208: TensorSpec(shape=(1, 1, 80, 80), dtype=tf.float32, name=None)
#   139660528996368: TensorSpec(shape=(80,), dtype=tf.float32, name=None)
#   139660813880976: TensorSpec(shape=(80,), dtype=tf.float32, name=None)
#   139660531349840: TensorSpec(shape=(1, 1, 16, 4), dtype=tf.float32, name=None)
#   139660813877904: TensorSpec(shape=(1, 1, 16, 4), dtype=tf.float32, name=None)
#   139660533538768: TensorSpec(shape=(1, 1, 16, 4), dtype=tf.float32, name=None)
#   139660528992336: TensorSpec(shape=(4,), dtype=tf.float32, name=None)
#   139660813877520: TensorSpec(shape=(4,), dtype=tf.float32, name=None)
#   139660533539536: TensorSpec(shape=(4,), dtype=tf.float32, name=None)
#   139660528997904: TensorSpec(shape=(1, 1, 80, 80), dtype=tf.float32, name=None)
#   139660813881744: TensorSpec(shape=(1, 1, 80, 80), dtype=tf.float32, name=None)
#   139660533544336: TensorSpec(shape=(1, 1, 80, 80), dtype=tf.float32, name=None)
#   139660528996944: TensorSpec(shape=(80,), dtype=tf.float32, name=None)
#   139660813881936: TensorSpec(shape=(80,), dtype=tf.float32, name=None)
#   139660533545488: TensorSpec(shape=(80,), dtype=tf.float32, name=None)
#   139660528993872: TensorSpec(shape=(3,), dtype=tf.int64, name=None)
#   139660528993488: TensorSpec(shape=(3,), dtype=tf.int64, name=None)
#   139660528995216: TensorSpec(shape=(3,), dtype=tf.int64, name=None)
#   139660528993296: TensorSpec(shape=(3,), dtype=tf.int64, name=None)
#   139660528996752: TensorSpec(shape=(1, 2, 8400), dtype=tf.float32, name=None)
#   139660528993680: TensorSpec(shape=(1, 2, 8400), dtype=tf.float32, name=None)
#   139660529000016: TensorSpec(shape=(), dtype=tf.int64, name=None)
#   139660529002896: TensorSpec(shape=(2, 1), dtype=tf.int32, name=None)
#   139660528999632: TensorSpec(shape=(2,), dtype=tf.int32, name=None)
#   139660529005584: TensorSpec(shape=(), dtype=tf.float32, name=None)
#   139660529003280: TensorSpec(shape=(), dtype=tf.int64, name=None)
#   139660529006352: TensorSpec(shape=(2, 1), dtype=tf.int32, name=None)
#   139660529004624: TensorSpec(shape=(2,), dtype=tf.int32, name=None)
#   139660528994448: TensorSpec(shape=(), dtype=tf.int64, name=None)
# TensorFlow SavedModel: export success ✅ 58.7s, saved as 'yolo26b_saved_model' (25.0 MB)
#
# TensorFlow GraphDef: starting export with tensorflow 2.19.0...
# TensorFlow GraphDef: export success ✅ 3.0s, saved as 'yolo26b.pb' (9.6 MB)
# <p style="margin:0px;">🌲 Try <a href="https://ydf.readthedocs.io/en/latest/" target="_blank">YDF</a>, the successor of
#     <a href="https://www.tensorflow.org/decision_forests" target="_blank">TensorFlow
#         Decision Forests</a> using the same algorithms but with more features and faster
#     training!
# </p>
# <div style="display: flex; flex-wrap: wrap; margin:5px;max-width: 880px;">
#     <div style="flex: 1; border-radius: 10px; background-color: F0F0F0; padding: 5px;">
#         <p
#             style="font-weight: bold; margin:0px;text-align: center;border-bottom: 1px solid #C0C0C0;margin-bottom: 4px;">
#             Old code</p>
#         <pre style="overflow-wrap: anywhere; overflow: auto; margin:0px;font-size: 9pt;">
# import tensorflow_decision_forests as tfdf
#
# tf_ds = tfdf.keras.pd_dataframe_to_tf_dataset(ds, label="l")
# model = tfdf.keras.RandomForestModel(label="l")
# model.fit(tf_ds)
# </pre>
#     </div>
#     <div style="width: 5px;"></div>
#     <div style="flex: 1; border-radius: 10px; background-color: F0F0F0; padding: 5px;">
#         <p
#             style="font-weight: bold; margin:0px;text-align: center;border-bottom: 1px solid #C0C0C0;margin-bottom: 4px;">
#             New code</p>
#         <pre style="overflow-wrap: anywhere; overflow: auto; margin:0px;font-size: 9pt;">
# import ydf
#
# model = ydf.RandomForestLearner(label="l").train(ds)
# </pre>
#     </div>
# </div>
# <p style="margin:0px;font-size: 9pt;">(Learn more in the <a
#         href="https://ydf.readthedocs.io/en/latest/tutorial/migrating_to_ydf/" target="_blank">migration
#         guide</a>)</p>
# TensorFlow.js: starting export with tensorflowjs 4.22.0...
#
# TensorFlow.js: output node names: Identity:0,model_95/tf.math.top_k/TopKV2:0
# TensorFlow.js: running 'tensorflowjs_converter --input_format=tf_frozen_model --output_node_names=Identity:0,model_95/tf.math.top_k/TopKV2:0 yolo26b.pb yolo26b_web_model/'
# TensorFlow.js: export success ✅ 8.2s, saved as 'yolo26b_web_model/' (10.0 MB)
#
# Export complete (71.6s)
# Results saved to /content/yolo26b_web_model
# Visualize:       https://netron.app
# 'yolo26b_web_model/'
